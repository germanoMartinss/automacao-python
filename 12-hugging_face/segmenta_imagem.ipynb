# %%
from transformers import pipeline

# %%
image_path = "img/fefe.png"
pipe = pipeline("image-segmentation", model="briaai/RMBG-1.4", trust_remote_code=True)
pillow_mask = pipe(image_path, return_mask=True)
pillow_image = pipe(image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 image_path = "img/fefe.png"
# ----> 2 pipe = pipeline("image-segmentation", model="briaai/RMBG-1.4", trust_remote_code=True)
#       3 pillow_mask = pipe(image_path, return_mask=True)
#       4 pillow_image = pipe(image_path)
#
# File ~/Documentos/Automação Completa com Python/venv/lib/python3.10/site-packages/transformers/pipelines/__init__.py:1024, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1019         raise ValueError(
#    1020             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1021             " arguments might conflict, use only one.)"
#    1022         )
#    1023 if dtype is not None:
# -> 1024     if isinstance(dtype, str) and hasattr(torch, dtype):
#    1025         dtype = getattr(torch, dtype)
#    1026     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined
