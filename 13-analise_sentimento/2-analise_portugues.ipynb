# %%
from pysentimiento import create_analyzer

# %%
model_analyser_sent = create_analyzer(task="sentiment", lang="pt")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/952 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  540MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/562 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/799k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %%
phrase1 = "O Santos é o melhor time do Brasil"
phrase2 = "O presidente do Santos precisa ser substituído urgentemente"
phrase3 = "O céu é azul"

# %%
model_analyser_sent.predict(phrase1)
# Out:
# AnalyzerOutput(output=POS, probas={POS: 0.987, NEU: 0.011, NEG: 0.002})

# %%
model_analyser_sent.predict(phrase2)
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.867, NEU: 0.117, POS: 0.017})

# %%
model_analyser_sent.predict(phrase3)
# Out:
# AnalyzerOutput(output=NEU, probas={NEU: 0.551, POS: 0.442, NEG: 0.006})
